# %% [markdown]
# # Biohub Kaggle inference adapter
#
# Milestones 0–1 only: prediction is intentionally disabled until official data inspection succeeds. This notebook will later discover `/kaggle/input` dynamically, call the core library, validate, and write `/kaggle/working/submission.csv` without internet access.
