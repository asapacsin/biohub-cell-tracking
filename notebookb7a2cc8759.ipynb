# %%
from pathlib import Path

DATASET_DIR = Path(
    "/kaggle/input/datasets/asapacsinfarland/biohub-result"
)

print(DATASET_DIR)
print(list(DATASET_DIR.iterdir()))
# Out:
# /kaggle/input/datasets/asapacsinfarland/biohub-result
# [PosixPath('/kaggle/input/datasets/asapacsinfarland/biohub-result/submission.csv')]
